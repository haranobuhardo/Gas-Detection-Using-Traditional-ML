# %% [markdown]
# # Data Modeling
# In this step the model creation will be started. Before we start creating the model, we will first find the best parameters (hyperparamter tuning) to be used in the model fitting with grid search cross-validation technique.
#
# We are going to use two machine learning model type in this project case, which are Random Forest technique and k-Nearest Neighbors technique with similar treatments. Random Forest is used here to check each sensors feature importance on each class classification.
#
# In each modeling process (hyperparameter tuning and model fitting) we will log the process and its result, and then save it to log files.

# %%
import sys
sys.path.append('..')

# %%
import src.util as utils

import json
import os
from datetime import datetime as dt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.model_selection import GridSearchCV

# %%
os.chdir(os.path.dirname(os.getcwd()))
os.getcwd()
# Out:
# 'd:\\ML\\PACMANN INTRO PROJECT'

# %%
config = utils.load_config()

# %% [markdown]
# ### Data Loading

# %%
X_train_feng = utils.pickle_load(config['train_feng_set_path'][0])
y_train_feng = utils.pickle_load(config['train_feng_set_path'][1])
X_test_feng = utils.pickle_load(config['test_feng_set_path'][0])
y_test_feng = utils.pickle_load(config['test_feng_set_path'][1])
X_val_feng = utils.pickle_load(config['val_feng_set_path'][0])
y_val_feng = utils.pickle_load(config['val_feng_set_path'][1])

# %% [markdown]
# ### Define logging functions

# %%
def time_stamp(to_str = False):
    if to_str:
        return dt.now().strftime("%Y-%m-%d %H:%M:%S")
    else:
        return dt.now()

# %%
def log_json(current_log: dict, log_path: str):
    current_log = current_log.copy()

    try:
        with open(log_path, "r") as file:
            last_log = json.load(file)
        file.close()
    except FileNotFoundError as ffe:
        with open(log_path, "w") as file:
            file.write("[]")
        file.close()
        with open(log_path, "r") as file:
            last_log = json.load(file)
        file.close()
    
    last_log.append(current_log)

    with open(log_path, "w") as file:
        json.dump(last_log, file)
        file.close()

    return last_log

# %%
def log_json(logs: dict, file_path: str):
    try:
        # Check if the file exists, and create it if it doesn't
        if not os.path.exists(file_path):
            with open(file_path, 'w') as f:
                pass

        # Log the JSON data
        with open(file_path, 'a') as f:
            json.dump(logs, f)
            f.write('\n')  # Add a newline for better readability of the log file

    except Exception as e:
        print(f"Error while logging JSON data: {e}")

# %% [markdown]
# ### Hyperparameter Tuning (Random Forest model)
# Using grid search cross-val, we will find the best n-estimators, tree max-depth, min samples split and min samples leaf.

# %%
# Grid search for RandomForest hyperparameters
rf = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train_feng, y_train_feng)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best hyperparameters:", best_params)
# Out:
# Best hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.070870      0.009679         0.005997        0.001863
# 1         0.332874      0.029619         0.013863        0.002389
# 2         0.627023      0.048648         0.026796        0.003165
# 3         1.330774      0.068554         0.055037        0.003295
# 4         0.060414      0.003960         0.003605        0.000374
# ..             ...           ...              ...             ...
# 139       1.231304      0.010476         0.053834        0.005179
# 140       0.065155      0.003431         0.004400        0.001356
# 141       0.300605      0.013107         0.013824        0.000685
# 142       0.603601      0.027730         0.028446        0.003920
# 143       1.044592      0.036910         0.036411        0.007523
#
#     param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0              None                      1                       2
# 1              None                      1                       2
# 2              None                      1                       2
# 3              None                      1                       2
# 4              None                      1                       5
# ..              ...                    ...                     ...
# 139              30                      4                       5
# 140              30                      4                      10
# 141              30                      4                      10
# 142              30                      4                      10
# 143              30                      4                      10
#
#     param_n_estimators                                             params  \
# 0                   10  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 1                   50  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 2                  100  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 3                  200  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 4                   10  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# ..                 ...                                                ...
# 139                200  {'max_depth': 30, 'min_samples_leaf': 4, 'min_...
# 140                 10  {'max_depth': 30, 'min_samples_leaf': 4, 'min_...
# 141                 50  {'max_depth': 30, 'min_samples_leaf': 4, 'min_...
# 142                100  {'max_depth': 30, 'min_samples_leaf': 4, 'min_...
# 143                200  {'max_depth': 30, 'min_samples_leaf': 4, 'min_...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 0             0.970938           0.968296           0.951058
# 1             0.970938           0.970938           0.958995
# 2             0.972259           0.969617           0.960317
# 3             0.972259           0.970938           0.961640
# 4             0.961691           0.959049           0.957672
# ..                 ...                ...                ...
# 139           0.959049           0.957728           0.956349
# 140           0.961691           0.961691           0.956349
# 141           0.960370           0.957728           0.955026
# 142           0.963012           0.957728           0.953704
# 143           0.959049           0.956407           0.953704
#
#      split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0             0.973545           0.968254         0.966418        0.007925
# 1             0.974868           0.969577         0.969063        0.005336
# 2             0.972222           0.969577         0.968798        0.004402
# 3             0.972222           0.968254         0.969063        0.003987
# 4             0.969577           0.965608         0.962719        0.004368
# ..                 ...                ...              ...             ...
# 139           0.965608           0.962963         0.960339        0.003437
# 140           0.964286           0.956349         0.960073        0.003185
# 141           0.966931           0.961640         0.960339        0.004005
# 142           0.966931           0.962963         0.960868        0.004625
# 143           0.968254           0.962963         0.960075        0.005106
#
#      rank_test_score
# 0                 25
# 1                  1
# 2                  8
# 3                  4
# 4                 55
# ..               ...
# 139               97
# 140              118
# 141              104
# 142               93
# 143              109
#
# [144 rows x 17 columns]

# %% [markdown]
# Save hyperparameter tuning results to log file json.

# %%
_grid_search_result_df = pd.DataFrame(grid_search.cv_results_)
_grid_search_result_df['timestamp'] = time_stamp(to_str=True)
log_json(_grid_search_result_df.to_dict(), config['hyperparameter_tuning_log_path'])

# %% [markdown]
# ### Hyperparameter Tuning (kNN model)
# Using grid search cross-val, we will find the best n-neighbors, weights, knn algorithm (ball tree or kd tree) and leaf size.

# %%
# Grid search for kNN hyperparameters
knn = KNeighborsClassifier()

param_grid_knn = {
    'n_neighbors': [5, 10, 20],
    'weights': ['uniform', 'distance'],
    'algorithm': ['ball_tree', 'kd_tree'],
    'leaf_size': [10, 30, 50]
}

grid_search_knn = GridSearchCV(estimator=knn, param_grid=param_grid_knn, cv=5, scoring='accuracy', n_jobs=-1)
grid_search_knn.fit(X_train_feng, y_train_feng)

# Get the best hyperparameters
best_params = grid_search_knn.best_params_
print("Best hyperparameters:", best_params)
# Out:
# Best hyperparameters: {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 5, 'weights': 'distance'}

# %%
pd.DataFrame(grid_search_knn.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003200      0.000400         0.045002        0.004337
# 1        0.004599      0.000799         0.012201        0.002227
# 2        0.007601      0.006218         0.048921        0.004315
# 3        0.004903      0.000915         0.012905        0.000660
# 4        0.004702      0.000605         0.050000        0.008576
# 5        0.004199      0.000400         0.015395        0.000489
# 6        0.003800      0.000749         0.044800        0.001033
# 7        0.004201      0.001469         0.014407        0.001661
# 8        0.003902      0.000493         0.051689        0.002757
# 9        0.004641      0.001430         0.017402        0.001624
# 10       0.003799      0.001166         0.052472        0.005638
# 11       0.003502      0.000448         0.021545        0.002727
# 12       0.003600      0.000802         0.048973        0.003598
# 13       0.003600      0.000490         0.020885        0.004166
# 14       0.003800      0.000980         0.052194        0.003633
# 15       0.003509      0.001262         0.019315        0.000772
# 16       0.003001      0.000003         0.054933        0.003971
# 17       0.004430      0.002865         0.025038        0.002197
# 18       0.006396      0.000489         0.049729        0.009691
# 19       0.006191      0.000737         0.010266        0.000970
# 20       0.006110      0.000477         0.045352        0.002836
# 21       0.006202      0.001470         0.019230        0.008009
# 22       0.006704      0.000747         0.049571        0.003076
# 23       0.007398      0.001855         0.016865        0.001072
# 24       0.004400      0.000490         0.041166        0.005352
# 25       0.004800      0.000749         0.008966        0.000653
# 26       0.004637      0.000690         0.042334        0.005770
# 27       0.005400      0.001497         0.012737        0.003692
# 28       0.004828      0.000795         0.045775        0.002474
# 29       0.005200      0.001166         0.016232        0.001968
# 30       0.006133      0.003089         0.043436        0.006881
# 31       0.006103      0.003012         0.013734        0.005717
# 32       0.004734      0.001374         0.040334        0.004605
# 33       0.003807      0.002224         0.008317        0.002216
# 34       0.003596      0.000495         0.039837        0.012133
# 35       0.003398      0.000798         0.012903        0.002157
#
#    param_algorithm param_leaf_size param_n_neighbors param_weights  \
# 0        ball_tree              10                 5       uniform
# 1        ball_tree              10                 5      distance
# 2        ball_tree              10                10       uniform
# 3        ball_tree              10                10      distance
# 4        ball_tree              10                20       uniform
# 5        ball_tree              10                20      distance
# 6        ball_tree              30                 5       uniform
# 7        ball_tree              30                 5      distance
# 8        ball_tree              30                10       uniform
# 9        ball_tree              30                10      distance
# 10       ball_tree              30                20       uniform
# 11       ball_tree              30                20      distance
# 12       ball_tree              50                 5       uniform
# 13       ball_tree              50                 5      distance
# 14       ball_tree              50                10       uniform
# 15       ball_tree              50                10      distance
# 16       ball_tree              50                20       uniform
# 17       ball_tree              50                20      distance
# 18         kd_tree              10                 5       uniform
# 19         kd_tree              10                 5      distance
# 20         kd_tree              10                10       uniform
# 21         kd_tree              10                10      distance
# 22         kd_tree              10                20       uniform
# 23         kd_tree              10                20      distance
# 24         kd_tree              30                 5       uniform
# 25         kd_tree              30                 5      distance
# 26         kd_tree              30                10       uniform
# 27         kd_tree              30                10      distance
# 28         kd_tree              30                20       uniform
# 29         kd_tree              30                20      distance
# 30         kd_tree              50                 5       uniform
# 31         kd_tree              50                 5      distance
# 32         kd_tree              50                10       uniform
# 33         kd_tree              50                10      distance
# 34         kd_tree              50                20       uniform
# 35         kd_tree              50                20      distance
#
#                                                params  split0_test_score  \
# 0   {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...           0.970938
# 1   {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...           0.976222
# 2   {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...           0.961691
# 3   {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...           0.965654
# 4   {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...           0.952444
# 5   {'algorithm': 'ball_tree', 'leaf_size': 10, 'n...           0.965654
# 6   {'algorithm': 'ball_tree', 'leaf_size': 30, 'n...           0.970938
# 7   {'algorithm': 'ball_tree', 'leaf_size': 30, 'n...           0.976222
# 8   {'algorithm': 'ball_tree', 'leaf_size': 30, 'n...           0.961691
# 9   {'algorithm': 'ball_tree', 'leaf_size': 30, 'n...           0.965654
# 10  {'algorithm': 'ball_tree', 'leaf_size': 30, 'n...           0.952444
# 11  {'algorithm': 'ball_tree', 'leaf_size': 30, 'n...           0.965654
# 12  {'algorithm': 'ball_tree', 'leaf_size': 50, 'n...           0.970938
# 13  {'algorithm': 'ball_tree', 'leaf_size': 50, 'n...           0.976222
# 14  {'algorithm': 'ball_tree', 'leaf_size': 50, 'n...           0.961691
# 15  {'algorithm': 'ball_tree', 'leaf_size': 50, 'n...           0.965654
# 16  {'algorithm': 'ball_tree', 'leaf_size': 50, 'n...           0.952444
# 17  {'algorithm': 'ball_tree', 'leaf_size': 50, 'n...           0.965654
# 18  {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_n...           0.970938
# 19  {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_n...           0.976222
# 20  {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_n...           0.961691
# 21  {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_n...           0.965654
# 22  {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_n...           0.952444
# 23  {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_n...           0.965654
# 24  {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_n...           0.970938
# 25  {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_n...           0.976222
# 26  {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_n...           0.961691
# 27  {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_n...           0.965654
# 28  {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_n...           0.952444
# 29  {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_n...           0.965654
# 30  {'algorithm': 'kd_tree', 'leaf_size': 50, 'n_n...           0.970938
# 31  {'algorithm': 'kd_tree', 'leaf_size': 50, 'n_n...           0.976222
# 32  {'algorithm': 'kd_tree', 'leaf_size': 50, 'n_n...           0.961691
# 33  {'algorithm': 'kd_tree', 'leaf_size': 50, 'n_n...           0.965654
# 34  {'algorithm': 'kd_tree', 'leaf_size': 50, 'n_n...           0.952444
# 35  {'algorithm': 'kd_tree', 'leaf_size': 50, 'n_n...           0.965654
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.968296           0.953704           0.961640
# 1            0.970938           0.961640           0.964286
# 2            0.952444           0.953704           0.958995
# 3            0.968296           0.960317           0.969577
# 4            0.944518           0.947090           0.960317
# 5            0.960370           0.957672           0.968254
# 6            0.968296           0.953704           0.961640
# 7            0.970938           0.961640           0.964286
# 8            0.952444           0.953704           0.958995
# 9            0.968296           0.960317           0.969577
# 10           0.944518           0.947090           0.960317
# 11           0.960370           0.957672           0.968254
# 12           0.968296           0.953704           0.961640
# 13           0.970938           0.961640           0.964286
# 14           0.952444           0.953704           0.958995
# 15           0.968296           0.960317           0.969577
# 16           0.944518           0.947090           0.960317
# 17           0.960370           0.957672           0.968254
# 18           0.968296           0.953704           0.961640
# 19           0.970938           0.961640           0.964286
# 20           0.952444           0.953704           0.958995
# 21           0.968296           0.960317           0.969577
# 22           0.944518           0.947090           0.960317
# 23           0.960370           0.957672           0.968254
# 24           0.968296           0.953704           0.961640
# 25           0.970938           0.961640           0.964286
# 26           0.952444           0.953704           0.958995
# 27           0.968296           0.960317           0.969577
# 28           0.944518           0.947090           0.960317
# 29           0.960370           0.957672           0.968254
# 30           0.968296           0.953704           0.961640
# 31           0.970938           0.961640           0.964286
# 32           0.952444           0.953704           0.958995
# 33           0.968296           0.960317           0.969577
# 34           0.944518           0.947090           0.960317
# 35           0.960370           0.957672           0.968254
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.968254         0.964566        0.006240               13
# 1            0.974868         0.969591        0.005744                1
# 2            0.957672         0.956901        0.003406               25
# 3            0.962963         0.965361        0.003396                7
# 4            0.952381         0.951350        0.005431               31
# 5            0.961640         0.962718        0.003779               19
# 6            0.968254         0.964566        0.006240               13
# 7            0.974868         0.969591        0.005744                1
# 8            0.957672         0.956901        0.003406               25
# 9            0.962963         0.965361        0.003396                7
# 10           0.952381         0.951350        0.005431               31
# 11           0.961640         0.962718        0.003779               19
# 12           0.968254         0.964566        0.006240               13
# 13           0.974868         0.969591        0.005744                1
# 14           0.957672         0.956901        0.003406               25
# 15           0.962963         0.965361        0.003396                7
# 16           0.952381         0.951350        0.005431               31
# 17           0.961640         0.962718        0.003779               19
# 18           0.968254         0.964566        0.006240               13
# 19           0.974868         0.969591        0.005744                1
# 20           0.957672         0.956901        0.003406               25
# 21           0.962963         0.965361        0.003396                7
# 22           0.952381         0.951350        0.005431               31
# 23           0.961640         0.962718        0.003779               19
# 24           0.968254         0.964566        0.006240               13
# 25           0.974868         0.969591        0.005744                1
# 26           0.957672         0.956901        0.003406               25
# 27           0.962963         0.965361        0.003396                7
# 28           0.952381         0.951350        0.005431               31
# 29           0.961640         0.962718        0.003779               19
# 30           0.968254         0.964566        0.006240               13
# 31           0.974868         0.969591        0.005744                1
# 32           0.957672         0.956901        0.003406               25
# 33           0.962963         0.965361        0.003396                7
# 34           0.952381         0.951350        0.005431               31
# 35           0.961640         0.962718        0.003779               19

# %% [markdown]
# Save hyperparameter tuning results to log file json.

# %%
_grid_search_result_df = pd.DataFrame(grid_search_knn.cv_results_)
_grid_search_result_df['timestamp'] = time_stamp(to_str=True)
log_json(_grid_search_result_df.to_dict(), config['hyperparameter_tuning_log_path'])

# %% [markdown]
# ### Model Training
# Model training based on the best parameters generated from hyperparameter tuning process.

# %%
# Train the model with the best hyperparameters
start_time = time_stamp()

clf = RandomForestClassifier(**grid_search.best_params_, random_state=42)
clf.fit(X_train_feng, y_train_feng)

finished_time = time_stamp()
elapsed_time = finished_time - start_time
elapsed_time = elapsed_time.total_seconds()

print("Training time elapsed:", elapsed_time, "s")
print("Classifier score on training data:", clf.score(X_train_feng, y_train_feng))
# Out:
# Training time elapsed: 0.263005 s
# Classifier score on training data: 1.0

# %%
# Train the model with the best hyperparameters
start_time = time_stamp()

knn_clf = KNeighborsClassifier(**grid_search_knn.best_params_)
knn_clf.fit(X_train_feng, y_train_feng)

finished_time = time_stamp()
elapsed_time = finished_time - start_time
elapsed_time = elapsed_time.total_seconds()

print("Training time elapsed:", elapsed_time, "s")
print("Classifier score on training data:", knn_clf.score(X_train_feng, y_train_feng))
# Out:
# Training time elapsed: 0.004025 s
# Classifier score on training data: 1.0

# %% [markdown]
# Check each trained model accuracy score on validation set

# %%
best_val_score = clf.score(X_val_feng, y_val_feng)
print(f'Best RF model accuracy score on val set: {best_val_score}')
# Out:
# Best RF model accuracy score on val set: 0.9703125

# %%
best_val_score = knn_clf.score(X_val_feng, y_val_feng)
print(f'Best kNN model accuracy score on val set: {best_val_score}')
# Out:
# Best kNN model accuracy score on val set: 0.971875

# %%
utils.pickle_dump(clf, config['production_model_path'])
utils.pickle_dump(knn_clf, config['knn_model_path'])
